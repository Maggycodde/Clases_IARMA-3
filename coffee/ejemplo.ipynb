# %% [markdown]
# ##############

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("synthetic_coffee_health_10000.csv")

print("Dataset cargado correctamente")
# Out:
# Dataset cargado correctamente

# %%
df.head()
# Out:
#    ID  Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0   1   40    Male  Germany            3.5        328.1          7.5
# 1   2   33    Male  Germany            1.0         94.1          6.2
# 2   3   42    Male   Brazil            5.3        503.7          5.9
# 3   4   53    Male  Germany            2.6        249.2          7.3
# 4   5   32  Female    Spain            3.1        298.0          5.3
#
#   Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# 0          Good  24.9          78          Low                     14.5
# 1          Good  20.0          67          Low                     11.0
# 2          Fair  22.7          59       Medium                     11.2
# 3          Good  24.7          71          Low                      6.6
# 4          Fair  24.1          76       Medium                      8.5
#
#   Health_Issues Occupation  Smoking  Alcohol_Consumption
# 0           NaN      Other        0                    0
# 1           NaN    Service        0                    0
# 2          Mild     Office        0                    0
# 3          Mild      Other        0                    0
# 4          Mild    Student        0                    1

# %%
df.tail()
# Out:
#          ID  Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 9995   9996   50  Female    Japan            2.1        199.8          6.0
# 9996   9997   18  Female       UK            3.4        319.2          5.8
# 9997   9998   26    Male    China            1.6        153.4          7.1
# 9998   9999   40  Female  Finland            3.4        327.1          7.0
# 9999  10000   42  Female   Brazil            2.9        277.5          6.4
#
#      Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# 9995          Fair  30.5          50       Medium                     10.1
# 9996          Fair  19.1          71       Medium                     11.6
# 9997          Good  25.1          66          Low                     13.7
# 9998          Good  19.3          80          Low                      0.1
# 9999          Good  28.1          72          Low                      9.8
#
#      Health_Issues  Occupation  Smoking  Alcohol_Consumption
# 9995      Moderate  Healthcare        0                    1
# 9996          Mild     Service        0                    0
# 9997           NaN     Student        1                    1
# 9998           NaN     Student        0                    0
# 9999           NaN     Student        1                    0

# %%
print("Filas: ", df.shape[0])
print("Columnas: ", df.shape[1])
# Out:
# Filas:  10000
# Columnas:  16

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       10000 non-null  int64
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  str
#  3   Country                  10000 non-null  str
#  4   Coffee_Intake            10000 non-null  float64
#  5   Caffeine_mg              10000 non-null  float64
#  6   Sleep_Hours              10000 non-null  float64
#  7   Sleep_Quality            10000 non-null  str
#  8   BMI                      10000 non-null  float64
#  9   Heart_Rate               10000 non-null  int64
#  10  Stress_Level             10000 non-null  str
#  11  Physical_Activity_Hours  10000 non-null  float64
#  12  Health_Issues            4059 non-null   str
#  13  Occupation               10000 non-null  str
#  14  Smoking                  10000 non-null  int64
#  15  Alcohol_Consumption      10000 non-null  int64
# dtypes: float64(5), int64(5), str(6)
# memory usage: 1.2 MB

# %%
df.dtypes
# Out:
# ID                           int64
# Age                          int64
# Gender                         str
# Country                        str
# Coffee_Intake              float64
# Caffeine_mg                float64
# Sleep_Hours                float64
# Sleep_Quality                  str
# BMI                        float64
# Heart_Rate                   int64
# Stress_Level                   str
# Physical_Activity_Hours    float64
# Health_Issues                  str
# Occupation                     str
# Smoking                      int64
# Alcohol_Consumption          int64
# dtype: object

# %%
df.describe()
# Out:
#                 ID           Age  Coffee_Intake   Caffeine_mg   Sleep_Hours  \
# count  10000.00000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    5000.50000     34.949100       2.509230    238.411010      6.636220
# std     2886.89568     11.160939       1.450248    137.748815      1.222055
# min        1.00000     18.000000       0.000000      0.000000      3.000000
# 25%     2500.75000     26.000000       1.500000    138.750000      5.800000
# 50%     5000.50000     34.000000       2.500000    235.400000      6.600000
# 75%     7500.25000     43.000000       3.500000    332.025000      7.500000
# max    10000.00000     80.000000       8.200000    780.300000     10.000000
#
#                 BMI    Heart_Rate  Physical_Activity_Hours      Smoking  \
# count  10000.000000  10000.000000              10000.00000  10000.00000
# mean      23.986860     70.617800                  7.48704      0.20040
# std        3.906411      9.822951                  4.31518      0.40032
# min       15.000000     50.000000                  0.00000      0.00000
# 25%       21.300000     64.000000                  3.70000      0.00000
# 50%       24.000000     71.000000                  7.50000      0.00000
# 75%       26.600000     77.000000                 11.20000      0.00000
# max       38.200000    109.000000                 15.00000      1.00000
#
#        Alcohol_Consumption
# count         10000.000000
# mean              0.300700
# std               0.458585
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               1.000000
# max               1.000000

# %%
df.isnull().sum()
# Out:
# ID                            0
# Age                           0
# Gender                        0
# Country                       0
# Coffee_Intake                 0
# Caffeine_mg                   0
# Sleep_Hours                   0
# Sleep_Quality                 0
# BMI                           0
# Heart_Rate                    0
# Stress_Level                  0
# Physical_Activity_Hours       0
# Health_Issues              5941
# Occupation                    0
# Smoking                       0
# Alcohol_Consumption           0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# ID                          0.00
# Age                         0.00
# Gender                      0.00
# Country                     0.00
# Coffee_Intake               0.00
# Caffeine_mg                 0.00
# Sleep_Hours                 0.00
# Sleep_Quality               0.00
# BMI                         0.00
# Heart_Rate                  0.00
# Stress_Level                0.00
# Physical_Activity_Hours     0.00
# Health_Issues              59.41
# Occupation                  0.00
# Smoking                     0.00
# Alcohol_Consumption         0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

print("Duplicados eliminados")
# Out:
# Duplicados eliminados

# %%
columnas_numericas = df.select_dtypes(include=[np.number]).columns

columnas_numericas
# Out:
# Index(['ID', 'Age', 'Coffee_Intake', 'Caffeine_mg', 'Sleep_Hours', 'BMI',
#        'Heart_Rate', 'Physical_Activity_Hours', 'Smoking',
#        'Alcohol_Consumption'],
#       dtype='str')

# %%
for columna in columnas_numericas:
    moda = df[columna].mode()[0]
    df[columna] = df[columna].fillna(df[columna].mean())
    
print("Valores numericos corregidos")
# Out:
# Valores numericos corregidos

# %%
columnas_categorias = df.select_dtypes(include='object').columns

columnas_categorias
# Out:
# C:\Users\Sarab\AppData\Local\Temp\ipykernel_19408\3633461309.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   columnas_categorias = df.select_dtypes(include='object').columns
# Index(['Gender', 'Country', 'Sleep_Quality', 'Stress_Level', 'Health_Issues',
#        'Occupation'],
#       dtype='str')

# %%
for columna in columnas_categoricas:
    moda = df[columna].mode()[0]
    df[columna] = df[columna].fillna(moda)

print("Valores categóricos corregidos")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 for columna in columnas_categoricas:
#       2     moda = df[columna].mode()[0]
#       3     df[columna] = df[columna].fillna(moda)
#       4
#
# NameError: name 'columnas_categoricas' is not defined

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    5001
# Male      4773
# Other      226
# Name: count, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# Country
# Canada         543
# India          524
# Norway         523
# China          521
# UK             519
# Sweden         513
# South Korea    512
# Finland        510
# Italy          509
# Switzerland    500
# France         499
# Germany        497
# Belgium        497
# Australia      497
# Netherlands    494
# Spain          486
# Mexico         483
# Japan          469
# Brazil         456
# USA            448
# Name: count, dtype: int64

# %%
df["Stress_Level"].value_counts()
# Out:
# Stress_Level
# Low       6989
# Medium    2050
# High       961
# Name: count, dtype: int64

# %%
df["Sleep_Quality"].value_counts()
# Out:
# Sleep_Quality
# Good         5637
# Fair         2050
# Excellent    1352
# Poor          961
# Name: count, dtype: int64

# %%
df["Grupo_Edad"] = pd.cut(
    df["Age"],
    bins=[0,18,30,45,60,100],
    labels=[
        "Menor",
        "Joven",
        "Adulto",
        "Maduro",
        "Adulto Mayor"
    ]
)

df[["Age","Grupo_Edad"]].head()
# Out:
#    Age Grupo_Edad
# 0   40     Adulto
# 1   33     Adulto
# 2   42     Adulto
# 3   53     Maduro
# 4   32     Adulto

# %%
df["Clasificacion_IMC"] = pd.cut(
    df["BMI"],
    bins=[0,18.5,24.9,29.9,100],
    labels=[
        "Bajo Peso",
        "Normal",
        "Sobrepeso",
        "Obesidad"
    ]
)

df[["BMI","Clasificacion_IMC"]].head()
# Out:
#     BMI Clasificacion_IMC
# 0  24.9            Normal
# 1  20.0            Normal
# 2  22.7            Normal
# 3  24.7            Normal
# 4  24.1            Normal

# %%
df["Grupo_Edad"].value_counts()
# Out:
# Grupo_Edad
# Adulto          4501
# Joven           2763
# Maduro          1653
# Menor            935
# Adulto Mayor     148
# Name: count, dtype: int64

# %%
df["Coffee_Intake"].mean()
# Out:
# np.float64(2.50923)

# %%
df["Caffeine_mg"].mean()
# Out:
# np.float64(238.41101)

# %%
df.groupby("Gender")["Coffee_Intake"].mean()
# Out:
# Gender
# Female    2.497720
# Male      2.522208
# Other     2.489823
# Name: Coffee_Intake, dtype: float64

# %%
df.groupby("Stress_Level")["Sleep_Hours"].mean()
# Out:
# Stress_Level
# High      4.451925
# Low       7.247332
# Medium    5.576732
# Name: Sleep_Hours, dtype: float64

# %%
df.groupby("Alcohol_Consumption")["Heart_Rate"].mean()
# Out:
# Alcohol_Consumption
# 0    70.678822
# 1    70.475890
# Name: Heart_Rate, dtype: float64

# %%
Q1 = df["Caffeine_mg"].quantile(0.25)
Q3 = df["Caffeine_mg"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

print("Límite inferior:", limite_inferior)
print("Límite superior:", limite_superior)
# Out:
# Límite inferior: -151.16249999999997
# Límite superior: 621.9375

# %%
outliers = df[
    (df["Caffeine_mg"] < limite_inferior) |
    (df["Caffeine_mg"] > limite_superior)
]

outliers
# Out:
#         ID  Age  Gender      Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 124    125   42  Female        Japan            7.6        722.4          7.5
# 128    129   36  Female        China            7.1        674.5          5.9
# 182    183   22    Male       Norway            7.6        723.9          6.0
# 306    307   50   Other  Netherlands            7.3        692.8          6.9
# 998    999   28    Male       Canada            6.7        638.5          5.3
# 1428  1429   32  Female  South Korea            6.7        639.5          6.4
# 1864  1865   50    Male  Netherlands            8.2        780.3          6.4
# 2259  2260   37    Male       Sweden            7.2        685.4          6.1
# 2276  2277   43    Male       Mexico            6.7        639.9          8.0
# 2705  2706   47    Male        Italy            7.3        693.4          6.0
# 2903  2904   38  Female           UK            7.0        663.8          7.1
# 3148  3149   33  Female       Norway            6.6        623.2          4.6
# 3153  3154   30  Female    Australia            7.8        742.2          5.2
# 3462  3463   36  Female  South Korea            6.7        638.6          6.6
# 3603  3604   35  Female        China            6.8        649.8          3.3
# 3682  3683   37    Male           UK            6.6        622.3          4.3
# 3696  3697   28    Male      Germany            7.0        663.9          7.0
# 3921  3922   37    Male          USA            7.7        733.1          7.9
# 4110  4111   48    Male  South Korea            7.3        693.8          4.7
# 4841  4842   35  Female  South Korea            6.9        650.8          6.5
# 4940  4941   42    Male        India            6.7        634.7          5.8
# 4959  4960   41  Female       France            6.6        623.1          7.2
# 5055  5056   21  Female       Canada            6.6        630.8          7.5
# 5289  5290   45  Female       Sweden            6.6        627.3          4.7
# 5617  5618   31  Female  Netherlands            6.7        635.0          4.6
# 6104  6105   24  Female      Belgium            7.8        738.8          6.0
# 6443  6444   45    Male           UK            6.9        656.6          7.1
# 6686  6687   28  Female       Canada            6.9        657.7          5.0
# 7157  7158   25  Female    Australia            6.7        634.8          5.8
# 7337  7338   18  Female       Mexico            6.7        640.8          7.1
# 7678  7679   26    Male       France            7.6        720.0          4.9
# 8032  8033   51  Female  South Korea            6.8        645.3          7.9
# 8427  8428   24    Male      Germany            6.8        644.9          4.3
# 8460  8461   25    Male          USA            7.7        729.2          7.2
# 8814  8815   38    Male       France            7.3        691.6          6.1
# 9409  9410   51    Male       France            6.6        630.3          4.2
# 9732  9733   50    Male       Brazil            6.6        627.4          5.0
# 9736  9737   40    Male       Canada            7.0        668.1          4.5
# 9962  9963   43  Female        India            7.0        665.4          4.8
#
#      Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# 124           Good  20.4          73          Low                     10.6
# 128           Fair  25.8          74       Medium                     14.8
# 182           Good  27.7          50          Low                      4.2
# 306           Good  28.8          60          Low                      6.8
# 998           Fair  27.3          66       Medium                      4.7
# 1428          Good  19.7          58          Low                      0.4
# 1864          Good  20.9          82          Low                     13.3
# 2259          Good  26.2          74          Low                     11.8
# 2276     Excellent  28.2          65          Low                     11.4
# 2705          Good  23.7          83          Low                      0.3
# 2903          Good  27.0          66          Low                      8.7
# 3148          Poor  22.2          63         High                      6.2
# 3153          Fair  29.4          71       Medium                     11.1
# 3462          Good  23.6          76          Low                      8.7
# 3603          Poor  27.9          74         High                     12.4
# 3682          Poor  23.2          76         High                      0.1
# 3696          Good  28.9          64          Low                      4.2
# 3921          Good  25.8          72          Low                      7.7
# 4110          Poor  27.7          99         High                      6.1
# 4841          Good  25.3          58          Low                     13.0
# 4940          Fair  15.2          78       Medium                      2.8
# 4959          Good  24.3          71          Low                     14.1
# 5055          Good  27.0          88          Low                      9.7
# 5289          Poor  20.7          78         High                     11.2
# 5617          Poor  19.8          63         High                     14.4
# 6104          Fair  30.0          69       Medium                      7.8
# 6443          Good  31.9          50          Low                     14.0
# 6686          Poor  16.9          74         High                     11.7
# 7157          Fair  20.3          53       Medium                      5.7
# 7337          Good  25.6          91          Low                     11.3
# 7678          Poor  25.1          74         High                     11.9
# 8032          Good  26.1          65          Low                      8.5
# 8427          Poor  23.8          70         High                      3.9
# 8460          Good  22.5          77          Low                      3.0
# 8814          Good  25.0          50          Low                      4.8
# 9409          Poor  15.0          73         High                      5.2
# 9732          Poor  26.3          85         High                     14.6
# 9736          Poor  27.7          67         High                      4.5
# 9962          Poor  20.8          55         High                     14.0
#
#      Health_Issues  Occupation  Smoking  Alcohol_Consumption Grupo_Edad  \
# 124            NaN      Office        0                    1     Adulto
# 128           Mild  Healthcare        0                    0     Adulto
# 182            NaN  Healthcare        0                    0      Joven
# 306            NaN       Other        0                    0     Maduro
# 998           Mild  Healthcare        0                    0      Joven
# 1428           NaN     Service        1                    0     Adulto
# 1864           NaN     Student        0                    0     Maduro
# 2259           NaN  Healthcare        0                    1     Adulto
# 2276           NaN       Other        0                    0     Adulto
# 2705           NaN     Service        0                    0     Maduro
# 2903           NaN     Student        0                    1     Adulto
# 3148          Mild  Healthcare        0                    1     Adulto
# 3153          Mild     Student        0                    0      Joven
# 3462           NaN  Healthcare        0                    0     Adulto
# 3603          Mild       Other        0                    0     Adulto
# 3682          Mild       Other        0                    0     Adulto
# 3696           NaN       Other        0                    1      Joven
# 3921           NaN      Office        0                    1     Adulto
# 4110          Mild     Student        0                    0     Maduro
# 4841           NaN  Healthcare        1                    0     Adulto
# 4940          Mild     Service        1                    1     Adulto
# 4959           NaN      Office        0                    0     Adulto
# 5055           NaN      Office        1                    1      Joven
# 5289          Mild     Student        0                    1     Adulto
# 5617          Mild  Healthcare        1                    0     Adulto
# 6104      Moderate       Other        1                    0      Joven
# 6443          Mild     Student        0                    0     Adulto
# 6686          Mild     Student        0                    0      Joven
# 7157          Mild     Service        1                    0      Joven
# 7337           NaN  Healthcare        0                    1      Menor
# 7678          Mild     Student        1                    0      Joven
# 8032          Mild     Service        0                    1     Maduro
# 8427          Mild     Student        0                    0      Joven
# 8460           NaN      Office        0                    0      Joven
# 8814           NaN     Student        0                    0     Adulto
# 9409      Moderate  Healthcare        0                    0     Maduro
# 9732          Mild     Service        0                    0     Maduro
# 9736          Mild     Student        0                    1     Adulto
# 9962          Mild  Healthcare        0                    1     Adulto
#
#      Clasificacion_IMC
# 124             Normal
# 128          Sobrepeso
# 182          Sobrepeso
# 306          Sobrepeso
# 998          Sobrepeso
# 1428            Normal
# 1864            Normal
# 2259         Sobrepeso
# 2276         Sobrepeso
# 2705            Normal
# 2903         Sobrepeso
# 3148            Normal
# 3153         Sobrepeso
# 3462            Normal
# 3603         Sobrepeso
# 3682            Normal
# 3696         Sobrepeso
# 3921         Sobrepeso
# 4110         Sobrepeso
# 4841         Sobrepeso
# 4940         Bajo Peso
# 4959            Normal
# 5055         Sobrepeso
# 5289            Normal
# 5617            Normal
# 6104          Obesidad
# 6443          Obesidad
# 6686         Bajo Peso
# 7157            Normal
# 7337         Sobrepeso
# 7678         Sobrepeso
# 8032         Sobrepeso
# 8427            Normal
# 8460            Normal
# 8814         Sobrepeso
# 9409         Bajo Peso
# 9732         Sobrepeso
# 9736         Sobrepeso
# 9962            Normal

# %%
print("Outliers encontrados:", len(outliers))
# Out:
# Outliers encontrados: 39

# %%
df.to_csv(
    "coffee_health_limpio.csv",
    index=False
)

print("Archivo exportado correctamente")
# Out:
# Archivo exportado correctamente

# %%
print("""
CONCLUSIONES

1. Se importó correctamente el conjunto de datos.
2. Se identificaron valores nulos y duplicados.
3. Se aplicaron técnicas de limpieza de datos.
4. Se generaron nuevas variables mediante transformación.
5. Se analizaron relaciones entre consumo de café,
   calidad del sueño y nivel de estrés.
6. Se identificaron valores atípicos utilizando IQR.
7. Se generó un nuevo dataset limpio para futuros análisis.
""")
# Out:
# CONCLUSIONES
#
# 1. Se importó correctamente el conjunto de datos.
# 2. Se identificaron valores nulos y duplicados.
# 3. Se aplicaron técnicas de limpieza de datos.
# 4. Se generaron nuevas variables mediante transformación.
# 5. Se analizaron relaciones entre consumo de café,
#    calidad del sueño y nivel de estrés.
# 6. Se identificaron valores atípicos utilizando IQR.
# 7. Se generó un nuevo dataset limpio para futuros análisis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Coffee_Intake"], kde=True)
plt.title("Distribución del Consumo de Café")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["Caffeine_mg"])
plt.title("Detección de Outliers en Cafeína")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="Coffee_Intake",
    y="Sleep_Hours",
    data=df
)
plt.title("Consumo de Café vs Horas de Sueño")
plt.show()
