# %% [markdown]
# ==========================================
# ANALISIS EXPLORATORIO DE DATOS CON PANDAS
# Dataset: crime.csv
# ==========================================
# Autor: Sara Margarita Gonzalez Burgos
# Materia: Analítica de Datos
# Objetivo:
# Aplicar técnicas de análisis, limpieza,
# transformación y exploración de datos.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("crime.csv")

print("Dataset cargado correctamente")
# Out:
# Dataset cargado correctamente

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808        Y  2018-09-02 13:00:00  2018      9
# 1      C11            347        Y  2018-08-21 00:00:00  2018      8
# 2       D4            151        Y  2018-09-03 19:27:00  2018      9
# 3       D4            272        Y  2018-09-03 21:16:00  2018      9
# 4       B3            421        Y  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...

# %%
df.tail()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 319045   I050310906-00          3125    Warrant Arrests
# 319046   I030217815-08           111           Homicide
# 319047   I030217815-08          3125    Warrant Arrests
# 319048   I010370257-00          3125    Warrant Arrests
# 319049       142052550          3125    Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 319045                       WARRANT ARREST       D4            285        Y
# 319046  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18            520        Y
# 319047                       WARRANT ARREST      E18            520        Y
# 319048                       WARRANT ARREST      E13            569        Y
# 319049                       WARRANT ARREST       D4            903        Y
#
#            OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 319045  2016-06-05 17:25:00  2016      6      Sunday    17  Part Three
# ...

# %%
print("Filas:", df.shape[0])
print("Columnas:", df.shape[1])
# Out:
# Filas: 319050
# Columnas: 19

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 319050 entries, 0 to 319049
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      319050 non-null  str
#  1   OFFENSE_CODE         319050 non-null  int64
#  2   OFFENSE_CODE_GROUP   319050 non-null  str
#  3   OFFENSE_DESCRIPTION  319050 non-null  str
#  4   DISTRICT             319050 non-null  str
#  5   REPORTING_AREA       319050 non-null  str
#  6   SHOOTING             319050 non-null  str
#  7   OCCURRED_ON_DATE     319050 non-null  str
#  8   YEAR                 319050 non-null  int64
#  9   MONTH                319050 non-null  int64
#  10  DAY_OF_WEEK          319050 non-null  str
#  11  HOUR                 319050 non-null  int64
#  12  UCR_PART             319050 non-null  str
#  13  STREET               319050 non-null  str
#  14  Lat                  319050 non-null  float64
# ...

# %%
df.dtypes
# Out:
# INCIDENT_NUMBER            str
# OFFENSE_CODE             int64
# OFFENSE_CODE_GROUP         str
# OFFENSE_DESCRIPTION        str
# DISTRICT                   str
# REPORTING_AREA             str
# SHOOTING                   str
# OCCURRED_ON_DATE           str
# YEAR                     int64
# MONTH                    int64
# DAY_OF_WEEK                str
# HOUR                     int64
# UCR_PART                   str
# STREET                     str
# Lat                    float64
# Long                   float64
# Location                   str
# Grupo_Temporada            str
# Grupo_Horario              str
# dtype: object

# %%
df.describe()
# Out:
#         OFFENSE_CODE           YEAR          MONTH           HOUR  \
# count  319050.000000  319050.000000  319050.000000  319050.000000
# mean     2317.516957    2016.560674       6.609622      13.118176
# std      1185.308921       0.996312       3.273677       6.294258
# min       111.000000    2015.000000       1.000000       0.000000
# 25%      1001.000000    2016.000000       4.000000       9.000000
# 50%      2907.000000    2017.000000       7.000000      14.000000
# 75%      3201.000000    2017.000000       9.000000      18.000000
# max      3831.000000    2018.000000      12.000000      23.000000
#
#                  Lat           Long
# count  319050.000000  319050.000000
# mean       42.214373     -70.908260
# std         2.091060       3.382480
# min        -1.000000     -71.178674
# 25%        42.290736     -71.095264
# 50%        42.321060     -71.075608
# 75%        42.347174     -71.060005
# max        42.395042      -1.000000

# %%
df.isnull().sum()
# Out:
# INCIDENT_NUMBER            0
# OFFENSE_CODE               0
# OFFENSE_CODE_GROUP         0
# OFFENSE_DESCRIPTION        0
# DISTRICT                   0
# REPORTING_AREA             0
# SHOOTING                   0
# OCCURRED_ON_DATE           0
# YEAR                       0
# MONTH                      0
# DAY_OF_WEEK                0
# HOUR                       0
# UCR_PART                   0
# STREET                     0
# Lat                        0
# Long                       0
# Location                   0
# Grupo_Temporada            0
# Grupo_Horario          15106
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# INCIDENT_NUMBER        0.000000
# OFFENSE_CODE           0.000000
# OFFENSE_CODE_GROUP     0.000000
# OFFENSE_DESCRIPTION    0.000000
# DISTRICT               0.000000
# REPORTING_AREA         0.000000
# SHOOTING               0.000000
# OCCURRED_ON_DATE       0.000000
# YEAR                   0.000000
# MONTH                  0.000000
# DAY_OF_WEEK            0.000000
# HOUR                   0.000000
# UCR_PART               0.000000
# STREET                 0.000000
# Lat                    0.000000
# Long                   0.000000
# Location               0.000000
# Grupo_Temporada        0.000000
# Grupo_Horario          4.734681
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

print("Duplicados eliminados")
# Out:
# Duplicados eliminados

# %%
columnas_numericas = df.select_dtypes(include=np.number).columns

columnas_numericas
# Out:
# Index(['OFFENSE_CODE', 'YEAR', 'MONTH', 'HOUR', 'Lat', 'Long'], dtype='str')

# %%
for columna in columnas_numericas:
    df[columna] = df[columna].fillna(df[columna].mean())

print("Valores numéricos corregidos")
# Out:
# Valores numéricos corregidos

# %%
columnas_categoricas = df.select_dtypes(include='object').columns

columnas_categoricas
# Out:
# C:\Users\Sarab\AppData\Local\Temp\ipykernel_17028\758409947.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   columnas_categoricas = df.select_dtypes(include='object').columns
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE_GROUP', 'OFFENSE_DESCRIPTION',
#        'DISTRICT', 'REPORTING_AREA', 'SHOOTING', 'OCCURRED_ON_DATE',
#        'DAY_OF_WEEK', 'UCR_PART', 'STREET', 'Location', 'Grupo_Temporada',
#        'Grupo_Horario'],
#       dtype='str')

# %%
for columna in columnas_categoricas:
    moda = df[columna].mode()[0]
    df[columna] = df[columna].fillna(moda)

print("Valores categóricos corregidos")
# Out:
# Valores categóricos corregidos

# %%
df["HOUR"].value_counts()
# Out:
# HOUR
# 17    20762
# 18    20301
# 16    19870
# 12    18676
# 19    17587
# 14    17189
# 13    16845
# 15    16519
# 11    16445
# 10    16345
# 20    15849
# 0     15106
# 9     14740
# 21    14109
# 8     13042
# 22    12925
# 23    10596
# 1      9267
# 7      8850
# 2      7693
# 6      5026
# 3      4589
# 4      3408
# 5      3311
# Name: count, dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# (0.00000000, 0.00000000)       19998
# (42.34862382, -71.08277637)     1243
# (42.36183857, -71.05976489)     1208
# (42.28482577, -71.09137369)     1121
# (42.32866284, -71.08563401)     1042
#                                ...
# (42.37972418, -71.06634439)        1
# (42.26333577, -71.12299894)        1
# (42.38272000, -71.02168200)        1
# (42.34647300, -71.09120200)        1
# (42.33987101, -71.16642615)        1
# Name: count, Length: 18194, dtype: int64

# %%
df["DISTRICT"].value_counts()
# Out:
# DISTRICT
# B2     51705
# C11    42528
# D4     41914
# A1     35710
# B3     35441
# C6     23457
# D14    20127
# E13    17534
# E18    17347
# A7     13544
# E5     13238
# A15     6505
# Name: count, dtype: int64

# %%
df["YEAR"].value_counts()
# Out:
# YEAR
# 2017    100884
# 2016     99110
# 2018     65685
# 2015     53371
# Name: count, dtype: int64

# %%
df["Grupo_Temporada"] = pd.cut(
    df["MONTH"],
    bins=[0,3,6,9,12],
    labels=[
        "Invierno",
        "Primavera",
        "Verano",
        "Otoño"
    ]
)

df[["MONTH","Grupo_Temporada"]].head()
# Out:
#    MONTH Grupo_Temporada
# 0      9          Verano
# 1      8          Verano
# 2      9          Verano
# 3      9          Verano
# 4      9          Verano

# %%
df["Grupo_Horario"] = pd.cut(
    df["HOUR"],
    bins=[0,6,12,18,24],
    labels=[
        "Madrugada",
        "Mañana",
        "Tarde",
        "Noche"
    ]
)

df[["HOUR","Grupo_Horario"]].head()
# Out:
#    HOUR Grupo_Horario
# 0    13         Tarde
# 1     0           NaN
# 2    19         Noche
# 3    21         Noche
# 4    21         Noche

# %%
df["Grupo_Temporada"].value_counts()
# Out:
# Grupo_Temporada
# Verano       95913
# Primavera    80850
# Otoño        72881
# Invierno     69406
# Name: count, dtype: int64

# %%
df["YEAR"].mean()
# Out:
# np.float64(2016.560673875568)

# %%
df["HOUR"].mean()
# Out:
# np.float64(13.118175834508698)

# %%
df.groupby("HOUR")["YEAR"].mean()
# Out:
# HOUR
# 0     2016.537667
# 1     2016.534046
# 2     2016.545171
# 3     2016.539115
# 4     2016.575117
# 5     2016.563878
# 6     2016.586550
# 7     2016.566667
# 8     2016.571078
# 9     2016.551696
# 10    2016.579810
# 11    2016.579690
# 12    2016.555794
# 13    2016.581953
# 14    2016.566351
# 15    2016.567286
# 16    2016.561802
# 17    2016.547105
# 18    2016.551254
# 19    2016.556377
# 20    2016.558142
# 21    2016.578780
# 22    2016.550948
# 23    2016.551529
# Name: YEAR, dtype: float64

# %%
df.groupby("INCIDENT_NUMBER")["YEAR"].mean()
# Out:
# INCIDENT_NUMBER
# 142052550        2015.0
# I010370257-00    2016.0
# I030217815-08    2015.0
# I050310906-00    2016.0
# I060168073-00    2018.0
#                   ...
# I182070938       2018.0
# I182070940       2018.0
# I182070941       2018.0
# I182070943       2018.0
# I182070945       2018.0
# Name: YEAR, Length: 282517, dtype: float64

# %%
df.groupby("STREET")["YEAR"].mean()
# Out:
# STREET
#  ALBANY ST             2015.071429
#  BLUE HILL AVE         2016.500000
#  COLUMBUS AVE          2015.000000
#  COMMONWEALTH AVE      2015.000000
#  MASSACHUSETTS AVE     2015.148148
#                           ...
# YUILL CIR              2016.000000
# ZAMORA CT              2017.000000
# ZAMORA ST              2017.000000
# ZEIGLER ST             2016.547368
# ZELLER ST              2017.000000
# Name: YEAR, Length: 4657, dtype: float64

# %%
Q1 = df["HOUR"].quantile(0.25)
Q3 = df["HOUR"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

print("Límite inferior:", limite_inferior)
print("Límite superior:", limite_superior)
# Out:
# Límite inferior: -4.5
# Límite superior: 31.5

# %%
outliers = df[
    (df["HOUR"] < limite_inferior) |
    (df["HOUR"] > limite_superior)
]

outliers
# Out:
# Empty DataFrame
# Columns: [INCIDENT_NUMBER, OFFENSE_CODE, OFFENSE_CODE_GROUP, OFFENSE_DESCRIPTION, DISTRICT, REPORTING_AREA, SHOOTING, OCCURRED_ON_DATE, YEAR, MONTH, DAY_OF_WEEK, HOUR, UCR_PART, STREET, Lat, Long, Location, Grupo_Temporada, Grupo_Horario]
# Index: []

# %%
print("Outliers encontrados:", len(outliers))
# Out:
# Outliers encontrados: 0

# %%
df.to_csv(
    "crime_limpio.csv",
    index=False
)

print("Archivo exportado correctamente")
# Out:
# Archivo exportado correctamente

# %%
print("""
CONCLUSIONES

1. Se importó correctamente el Dataset de 319,050 registros.
2. Se identifico que solo Grupo_Horario tenia 4.73% de datos nulos.
3. Se aplicaron técnicas de limpieza de datos.
4. Se generaron nuevas variables mediante transformación.
5. Se crearon Grupo_Temporada y Grupo_Horario para analizar la relacion de ocuurencia de crimenes 
en diferentes horarios y temporadas.
6. Se identificaron valores atípicos utilizando IQR.
7. Se generó un nuevo dataset limpio para futuros análisis.
""")
# Out:
# CONCLUSIONES
#
# 1. Se importó correctamente el Dataset de 319,050 registros.
# 2. Se identifico que solo Grupo_Horario tenia 4.73% de datos nulos.
# 3. Se aplicaron técnicas de limpieza de datos.
# 4. Se generaron nuevas variables mediante transformación.
# 5. Se crearon Grupo_Temporada y Grupo_Horario para analizar la relacion de ocuurencia de crimenes
# en diferentes horarios y temporadas.
# 6. Se identificaron valores atípicos utilizando IQR.
# 7. Se generó un nuevo dataset limpio para futuros análisis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["DISTRICT"], kde=True)
plt.title("Distribución de Incidentes por Distrito")
plt.xlabel("Distrito")
plt.ylabel("Cantidad de Incidentes")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["HOUR"])
plt.title("Distribución de outliers en Hora del Crimen")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="DISTRICT",
    y="OFFENSE_CODE",
    data=df
)
plt.title("Distribucion de Tipos de Ofensa por Distrito")
plt.show()
